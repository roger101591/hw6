# %%
from citipy import citipy
import matplotlib.pyplot as plt
import pandas as pd
import openweathermapy.core as owm
import random

# %%
city = citipy.nearest_city(6,1)
city = city.city_name
city
# Out:
# 'keta'

# %%
#get list of random cities
cities = []
while len(cities) < 500:
    latitude = random.randint(0,90)
    longitude = random.randint(0,180)
    city = citipy.nearest_city(latitude,longitude)
    city = city.city_name
    if city not in cities:
        cities.append(city)

citiesdf = pd.DataFrame(cities)
citiesdf
# Out:
#                    0
# 0         nikolskoye
# 1      belushya guba
# 2             dikson
# 3             gayeri
# 4         solnechnyy
# 5        nizhneyansk
# 6       sentyabrskiy
# 7           katangli
# 8              mezen
# 9    galyugayevskaya
# 10      beringovskiy
# 11           kavieng
# 12            hasaki
# 13          kawardha
# 14             vaxjo
# 15             hobyo
# 16          zyryanka
# 17          sobolevo
# 18             moron
# 19            ranong
# 20     leningradskiy
# 21      umm kaddadah
# 22            pravda
# 23           talnakh
# 24      palaikastron
# 25          khatanga
# 26       oktyabrskiy
# 27             jumla
# 28             chara
# 29          tasbuget
# ..               ...
# 470           chiusi
# 471           tawkar
# 472          aksarka
# 473          tazmalt
# 474      solovetskiy
# 475            nikel
# 476      palafrugell
# 477      san lawrenz
# 478           abalak
# 479         nykoping
# 480             zile
# 481         san jose
# 482          karaton
# 483         vilyuysk
# 484          kurchum
# 485          gulshat
# 486             qena
# 487           wahran
# 488          jiuquan
# 489        ondorhaan
# 490            ozgon
# 491          imabari
# 492     bogorodskoye
# 493       banda aceh
# 494        porbandar
# 495           panvel
# 496          buciumi
# 497          baculin
# 498           boddam
# 499             chik
#
# [500 rows x 1 columns]

# %%
#unique city check
city_list = citiesdf[0].value_counts()
city_list
# Out:
# tawkar                       1
# galyugayevskaya              1
# vaxjo                        1
# sobolevo                     1
# issoudun                     1
# jiaozuo                      1
# tonekabon                    1
# rawannawi                    1
# dabhol                       1
# bud                          1
# gat                          1
# kinanah                      1
# palimbang                    1
# cao bang                     1
# romny                        1
# bahir dar                    1
# igarka                       1
# vetluga                      1
# demmin                       1
# marawi                       1
# galashki                     1
# novolvovsk                   1
# ranong                       1
# aginskoye                    1
# abhar                        1
# abu dhabi                    1
# mudyuga                      1
# galle                        1
# chokurdakh                   1
# petropavlovsk-kamchatskiy    1
#                             ..
# pidhorodna                   1
# malwan                       1
# tumannyy                     1
# vardo                        1
# helong                       1
# punalur                      1
# kamyaran                     1
# manama                       1
# palasa                       1
# haibowan                     1
# miyako                       1
# manado                       1
# strezhevoy                   1
# sibolga                      1
# thinadhoo                    1
# shimoda                      1
# arman                        1
# tokmak                       1
# balatonalmadi                1
# abnub                        1
# umm kaddadah                 1
# hobyo                        1
# yuzhno-kurilsk               1
# bakchar                      1
# bhainsa                      1
# awbari                       1
# vostok                       1
# birao                        1
# durres                       1
# nizwa                        1
# Name: 0, Length: 500, dtype: int64
